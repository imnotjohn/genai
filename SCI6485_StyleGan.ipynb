# %% [markdown]
# # SCI6485 Introduction to Generative Artificial Intelligence
#
# ##  STYLEGAN3
#
#
# **Harvard University**<br/>
# **Fall 2023**<br/>
# **Instructor:**  Sabrina Osmany<br/>
# **TA:**  Jiabin Wei<br/>
#
# **DISCLAIMER**: No public reproduction of this code is allowed without the explicit consent of their authors.
#
# <hr style="height:2pt">
#
# ---

# %% [markdown]
#  This tutorial is heavily borrowed from this github [repo](https://github.com/derekphilipau/machinelearningforartists).

# %% [markdown]
# # Training custom data with StyleGAN
#
# In this tutorial, we only want to familiarize ourselves with running StyleGAN (in this case, the newest version) and seeing how training progresses.

# %% [markdown]
# ## Verify Runtime is GPU
#
# In the menu, select Runtime -> Change Runtime Type and verify you are using the **GPU**.  Also select **High-RAM** if you are using Colab Pro.
#
# The `nvidia-smi` command below should **NOT** display *"NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver."*

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-4570e217-90ba-2233-9a74-74738afdcd29)

# %% [markdown]
# ## Mount your Google Drive
#
# You will be storing the training models and progress images on your Google Drive.  This is very convenient for viewing progress, and if your Colab notebook is disconnected you will not lose your models.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install Stylegan pytorch Prerequisites

# %%
import torch
import torchvision
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# Selected device: cuda
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Collecting pyspng
#   Downloading pyspng-0.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (205 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.9/205.9 kB 4.0 MB/s eta 0:00:00
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 17.2 MB/s eta 0:00:00
# Collecting imageio-ffmpeg==0.4.3
#   Downloading imageio_ffmpeg-0.4.3-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 51.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyspng) (1.23.5)
# Installing collected packages: ninja, pyspng, imageio-ffmpeg
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.4.9
#     Uninstalling imageio-ffmpeg-0.4.9:
#       Successfully uninstalled imageio-ffmpeg-0.4.9
# Successfully installed imageio-ffmpeg-0.4.3 ninja-1.11.1.1 pyspng-0.1.1

# %% [markdown]
# ## Get the StyleGAN code

# %%
# clone StyleGan repo from github
# !git clone https://github.com/NVlabs/stylegan3
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 212 (delta 0), reused 1 (delta 0), pack-reused 207
# Receiving objects: 100% (212/212), 4.17 MiB | 26.55 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
# clone image dataset tool repo from github
# !git clone https://github.com/EmilioMichael/img_dataset_tool
# Out:
# Cloning into 'img_dataset_tool'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 8 (delta 1), reused 8 (delta 1), pack-reused 0
# Receiving objects: 100% (8/8), 6.50 KiB | 6.50 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
#  create a dataset folder under your stylegan directory

# %%
mkdir /content/stylegan3/datasets

# %% [markdown]
# ## Load a custom dataset

# %%
#######################################################
#      unzip the custome dataset zip file to the 'datasets' folder under the 'stylegan3' directory
#      you need to replace the path after 'unzip' with your zip file directory
#######################################################

# Custom datasets can be created from a folder containing images
# unzip your custom data zip file to stylegan3 dataset directory
# !unzip /content/drive/MyDrive/MDE/SCI6485/StyleGan/chinese_painting/chinese_landscape_paintings.zip -d /content/stylegan3/datasets
# Out:
# Archive:  /content/drive/MyDrive/MDE/SCI6485/StyleGan/chinese_painting/chinese_landscape_paintings.zip
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Smithsonian-6
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/.DS_Store
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._.DS_Store
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-1/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Smithsonian-1
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/met-1/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._met-1
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-7/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Smithsonian-7
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Princeton-2/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Princeton-2
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-2/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Smithsonian-2
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/met-2/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._met-2
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-5/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Smithsonian-5
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-4/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Smithsonian-4
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-3/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Smithsonian-3
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Princeton-1/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Princeton-1
#    creating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/._Harvard
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_962.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_962.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_989.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_989.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1058.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1058.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1064.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1064.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1070.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1070.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1138.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1138.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1110.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1110.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1104.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1104.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1105.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1105.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1111.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1111.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1139.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1139.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1071.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1071.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1065.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1065.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1059.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1059.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_988.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_988.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_963.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_963.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_961.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_961.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1073.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1073.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1067.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1067.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1098.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1098.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1107.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1107.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1113.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1113.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1112.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1112.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1106.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1106.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1099.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1099.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1066.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1066.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1072.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1072.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_960.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_960.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_970.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_970.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_964.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_964.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_958.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_958.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1076.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1076.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1062.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1062.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1089.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1089.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1102.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1102.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1116.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1116.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1117.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1117.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1103.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1103.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1088.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1088.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1063.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1063.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1077.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1077.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_959.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_959.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_965.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_965.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_971.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_971.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_967.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_967.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_998.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_998.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1061.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1061.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1075.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1075.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1049.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1049.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1115.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1115.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1101.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1101.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1129.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1129.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1128.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1128.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1100.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1100.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1114.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1114.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1048.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1048.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1074.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1074.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1060.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1060.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_999.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_999.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_966.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_966.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1007.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1007.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1013.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1013.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1012.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1012.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1006.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1006.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1038.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1038.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1010.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1010.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1004.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1004.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1158.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1158.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1005.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1005.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1011.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1011.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1039.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1039.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1015.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1015.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1001.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1001.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1029.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1029.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1149.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1149.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1148.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1148.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1028.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1028.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1000.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1000.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1014.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1014.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1002.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1002.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1016.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1016.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1017.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1017.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1003.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1003.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1026.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1026.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1032.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1032.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1152.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1152.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1146.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1146.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1147.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1147.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1153.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1153.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1033.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1033.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1027.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1027.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1019.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1019.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1031.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1031.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1025.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1025.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1145.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1145.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1151.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1151.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1150.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1150.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1144.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1144.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1024.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1024.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1030.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1030.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1018.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1018.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1034.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1034.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1020.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1020.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1008.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1008.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1140.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1140.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1154.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1154.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1155.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1155.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1141.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1141.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1009.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1009.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1021.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1021.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1035.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1035.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1023.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1023.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1037.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1037.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1157.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1157.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1143.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1143.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1142.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1142.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1156.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1156.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1036.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1036.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1022.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1022.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_957.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_957.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_980.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_980.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_994.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_994.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1079.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1079.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1045.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1045.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1051.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1051.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1086.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1086.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1092.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1092.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1119.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1119.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1131.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1131.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1125.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1125.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1124.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1124.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1130.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1130.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1118.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1118.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1093.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1093.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1087.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1087.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1050.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1050.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1044.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1044.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1078.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1078.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_995.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_995.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_981.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_981.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_956.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_956.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_968.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_968.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_954.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_954.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_997.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_997.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_983.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_983.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1052.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1052.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1046.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1046.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1091.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1091.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1085.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1085.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1126.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1126.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1132.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1132.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1133.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1133.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1127.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1127.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1084.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1084.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1090.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1090.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1047.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1047.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1053.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1053.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_982.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_982.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_996.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_996.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_955.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_955.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_969.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_969.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_951.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_951.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_992.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_992.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_986.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_986.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1057.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1057.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1043.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1043.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1094.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1094.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1080.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1080.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1123.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1123.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1137.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1137.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1136.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1136.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1122.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1122.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1081.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1081.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1095.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1095.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1042.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1042.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1056.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1056.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_987.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_987.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_993.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_993.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_952.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_952.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_985.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_985.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_991.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_991.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1040.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1040.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1054.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1054.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1068.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1068.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1083.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1083.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1097.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1097.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1134.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1134.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1120.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1120.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1108.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1108.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1109.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1109.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1121.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1121.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1135.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1135.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1096.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1096.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1082.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1082.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1069.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1069.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1055.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1055.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_1041.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_1041.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_990.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_990.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_984.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_984.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-6/smithsonian_953.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-6/._smithsonian_953.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-1/smithsonian_32.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-1/._smithsonian_32.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-1/smithsonian_26.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-1/._smithsonian_26.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-1/smithsonian_6.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-1/._smithsonian_6.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-1/smithsonian_194.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Smithsonian-1/._smithsonian_194.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Smithsonian-1/smithsonian_180.jpg
# ...
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_89.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_89.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_76.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_76.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_62.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_62.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_39.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_39.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_11.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_11.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_2.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_2.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_3.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_3.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_10.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_10.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_38.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_38.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_12.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_12.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_1.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_1.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_0.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_0.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_13.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_13.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_17.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_17.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_4.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_4.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_5.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_5.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_16.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_16.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_14.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_14.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_7.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_7.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_28.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_28.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_29.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_29.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_6.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_6.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_15.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_15.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_18.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_18.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_24.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_24.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_30.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_30.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_31.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_31.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_25.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_25.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_19.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_19.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_8.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_8.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_33.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_33.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_27.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_27.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_26.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_26.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_32.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_32.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_9.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_9.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_36.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_36.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_22.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_22.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_23.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_23.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_37.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_37.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_21.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_21.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_35.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_35.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_34.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_34.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_20.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_20.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_47.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_47.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_53.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_53.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_84.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_84.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_90.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_90.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_91.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_91.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_85.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_85.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_52.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_52.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_46.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_46.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_100.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_100.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_78.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_78.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_50.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_50.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_44.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_44.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_93.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_93.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_87.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_87.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_86.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_86.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_92.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_92.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_45.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_45.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_51.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_51.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_79.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_79.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_55.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_55.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_41.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_41.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_69.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_69.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_96.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_96.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_82.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_82.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_83.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_83.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_97.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_97.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_68.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_68.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_40.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_40.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_54.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_54.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_42.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_42.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_56.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_56.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_81.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_81.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_95.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_95.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_94.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_94.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_80.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_80.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_57.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_57.jpg
#   inflating: /content/stylegan3/datasets/chinese_landscape_paintings/Harvard/harvard_43.jpg
#   inflating: /content/stylegan3/datasets/__MACOSX/chinese_landscape_paintings/Harvard/._harvard_43.jpg

# %%
# remove the "__MACOSX" directory from a Unix-based file system, typically found in ZIP or compressed archives created on macOS.
# !rm -rf /content/stylegan3/datasets/__MACOSX

# %%
# %cd /content/stylegan3
# Out:
# /content/stylegan3

# %%
ls
# Out:
# avg_spectra.py   dnnlib/          gen_images.py  LICENSE.txt   training/
# calc_metrics.py  Dockerfile       gen_video.py   metrics/      train.py
# datasets/        docs/            gui_utils/     README.md     visualizer.py
# dataset_tool.py  environment.yml  legacy.py      torch_utils/  viz/

# %%
# !pwd
# Out:
# /content/stylegan3

# %% [markdown]
# ## Tips for training a StyleGAN3 with limited computing resources
# Generally, there are two ways to do it:
#
# I.  Make the training process more efficient <br>
# II. Make your custom dataset easier to train with <br>
# III. Resume the training with the latest training result<br>
# IV. Train your data with a pre-trained model (transfer learning)<br><br>
#
#
# **I. Make the training process faster**
#   * Reduce the resolution of images:
#
#   use smaller image size to reduce the number of trainable parameters
#   ```python
#   # you can also scale down the resolution of images here. You could use this line to check the explanation for the parameters: !python dataset_tool.py --help
#   !python dataset_tool.py --source=./datasets/custom_data_2 --dest=./datasets/customdataset.zip --resolution=16x16
#   ```
#   However, as the latent space dimension of the generator of the StyleGAN3 is fixed, reducing the resolution of your custom dataset only reduce the trainable parameter size in the discriminator in this model.
#
#   If you want to further reduce the trainiable parameters, you can use a less complex StyleGAN model. For example, Mark used another StyleGAN model in this [repo](https://github.com/TAUIL-Abd-Elilah/Generative-Adversarial-Networks--GANs/blob/main/StyleGAN%20implementation%20from%20scratch%20PyTorch.ipynb). It seems to be simpler than the StyleGAN3 used in this colab.
#
#   Although it may not very easy to change the model architecture, it is possile to make some minor changes to reduce the trainable parameters. For example,  we can use the ``cmap`` parameter to reduce the maximum channel size. Or use the ``map-depth`` parameter to set the number of mapping network layers, but we use the stylegan3-t model configuration in this colab, which only has 2 mapping network layers. You will find that ``cmap`` can greatly reduce the trainable parameters and the training time.
#
#   ```python
#   # train the model. change the batch size to a larger number but you should make sure that it won't
#   !python train.py --outdir=... --cfg=stylegan3-t --data=...  --gpus=1 --batch=32 --batch-gpu=4  --map-depth=2 --cmap=256 ...
#   ```
#   (Mapping network: is an essential component that takes a random noise vector as input and maps it to an intermediate latent space representation that controls the appearance of the generated images. The purpose of the mapping network is to learn a transformation that can shape the latent space in a way that makes it more amenable for generating high-quality images. This transformation helps disentangle different aspects of image generation, such as controlling factors like facial features, pose, and style. It separates the stochastic part from the deterministic part of image generation.)  <br><br>
#
#
#
#
#   * Mildly increase the image batch size:
#
#   When you train a deep learning model, you typically have a dataset consisting of a large number of training examples. The batch size specifies how many of these examples are loaded into memory at a time. For example, if you set the batch size to 32, the training process will load and process 32 examples at once in parallel. So if we increase the batch size  a little bit:
#
#     - Efficient GPU Utilization: With larger batch sizes, you can better utilize the parallel processing capabilities of modern GPUs, potentially speeding up training.
#     - Stable Gradients: Larger batch sizes can provide more stable and accurate gradient estimates, which can lead to more robust training.
#
#   ```python
#   # train the model. change the batch size to a larger number but you should make sure that it won't
#   !python train.py --outdir=... --cfg=stylegan3-t --data=...  --gpus=1 --batch=32 --batch-gpu=4...
#   ```
#
#   However, the batch size directly affects the GPU memory usage. Each example in the batch is stored in memory, and the intermediate activations and gradients are also stored for the purpose of backpropagation. The GPU processes the entire batch in parallel. The size of the batch must be small enough to fit within the available GPU memory. If the batch size is too large for the GPU to handle, you may encounter out-of-memory errors. <br><br>
#
# **II. Make your custom dataset easier to work with**
#
#   * Consistent Object or Scene Types:
#
#   Custom datasets that focus on a specific object or scene type can be easier for GANs to generate. For instance, a dataset of cats, dogs, or specific objects is generally easier to work with than a diverse collection of unrelated items.
#
#   * Large Inter-class Variability:
#
#   GANs can handle multiple classes, but you would better to make sure that the differences between different classes or categories are clear. For example, if you have a dataset of cars and bikes, the distinct differences in shape and appearance make it easier for GANs to generate these objects.
#
#   * Few Background Variations:
#
#   If the background of the images in your dataset remains relatively consistent, GANs can focus more on modeling the primary object or content.
#
#   * Consistent Lighting and Camera Conditions:
#
#   Datasets with consistent lighting and camera conditions are generally easier to work with. Changes in lighting, viewpoint, or camera conditions can introduce additional challenges for GANs.<br><br>
#
# **III. Resume the training with the latest training result**
#
#   * The StyleGAN3 model we use here will automatically save your training result every n ticks. The default n is 50 and you could set this n in with the ``snap`` parameter. You can also change the size of tick with the ``tick`` parameter. The default tick size is 4, which means that every 4k images, the model will save the snapshot.
#
#   ```python
#   #######################################################
#   #      set --outdir= as the directory you want to store your training result
#   #      set --data= as the compressed zip file generated by the dataset_tool.py from above
#   #######################################################
#
#   !python train.py --outdir=/content/drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test --cfg=stylegan3-t --data=./datasets/customdataset.zip  --gpus=1 --batch=32 --batch-gpu=4 --gamma=10.0 --mirror=1 --kimg=5000 --snap=1
#   ```
#
#   To resume the training process, you need to tell the train.py where the latest training result pkl is. You need modify value of the `resume` parameter in this code cell and put your latest pkl file directory here。
#
#   ```python
#   #######################################################
#   #      optional: fine tune a pretrained model
#   #      but you need to resize the images to fit the pre-trained model
#   #######################################################
#
#   !python train.py --outdir=/content/drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result --cfg=stylegan3-t --data=./datasets/customdataset.zip  --gpus=1 --batch=32 --batch-gpu=4 --gamma=10.0 --mirror=1 --kimg=5000 --snap=1 --resume=content/drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_2/00000-stylegan3-t-customdataset-gpus1-batch32-gamma10/network-snapshot-000012.pkl
#   ```
#
#   (Tick is another way to track the progress of the training process. For example, you may see information like "1M ticks" or "10M ticks," where "M" stands for million, indicating that a certain number of training images have been completed. We say one training image is completed when it goes through a single forward and backward pass through the network, and finish computing gradients and updating parameters.)<br><br>
#
#
# **IV. Train your data with a pre-trained model (transfer learning)**
#
#
#    * This suggesion is copied from the StyleGAN3 official [configuration doc](https://github.com/NVlabs/stylegan3/blob/main/docs/configs.md) :
#
#    Transfer learning makes it possible to reach very good results very quickly, especially when the training set is small and/or the images resemble the ones produced by a pre-trained model. To enable transfer learning, you can point --resume to one of the pre-trained models that we provide for StyleGAN3 and StyleGAN2. For example:
#
#   ```python
#   # Fine-tune StyleGAN3-R for MetFaces-U using 1 GPU, starting from the pre-trained FFHQ-U pickle.
#   python train.py --outdir=~/training-runs --cfg=stylegan3-r --data=~/datasets/metfacesu-1024x1024.zip \
#     --gpus=8 --batch=32 --gamma=6.6 --mirror=1 --kimg=5000 --snap=5 \
#     --resume=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhqu-1024x1024.pkl
#   ```
#
#   The pre-trained model should be selected to match the specified config, resolution, and architecture-related hyperparameters (e.g., --cbase, --map-depth, and --mbstd-group). You check this by looking at the fakes_init.png exported by train.py at the beginning; if the configuration is correct, the images should look reasonable.
#
#   With transfer learning, the results may be improved slightly by adjusting ``--freezed``, in addition to the above guidelines for ``--gamma``, ``--mirror``, and ``--aug``. In our experience, ``--freezed=10`` and ``--freezed=13`` tend to work reasonably well.

# %% [markdown]
# ## Prepare your custom dataset for use by StyleGAN

# %%
#######################################################
#      set --source= as the directory your dataset folder
#      set --dest= as the directory and the folder name of the new compressed zip file
#######################################################

# Datasets are stored as uncompressed ZIP archives containing uncompressed PNG files and a metadata file dataset.json for labels.
# !python dataset_tool.py --source=./datasets/custom_data --dest=./datasets/customdataset.zip

# you can also scale down the resolution of images here. You could use this line to check the explanation for the parameters: !python dataset_tool.py --help
# !python dataset_tool.py --source=./datasets/custom_data_2 --dest=./datasets/customdataset.zip --resolution=32x32
# !python dataset_tool.py --source=./datasets/chinese_landscape_paintings --dest=./datasets/customdataset.zip --resolution=512x512
# Out:
#   0% 0/2192 [00:00<?, ?it/s]Error: Image 00000/img00000004.png attributes must be equal across all images of the dataset.  Got:
#   dataset width/cur image width: 512/512
#   dataset height/cur image height: 512/512
#   dataset channels/cur image channels: 3/1
#   0% 4/2192 [00:00<00:40, 53.98it/s]

# %%
#######################################################
#      set --source= as the directory your dataset folder
#      set --dest= as the directory and the folder name of the new compressed zip file
#######################################################
# !python ../img_dataset_tool/dataset_tool.py --source=./datasets/chinese_landscape_paintings --dest=./datasets/customdataset.zip --resolution=128x128
# Out:
#   0% 0/2192 [00:00<?, ?it/s]skip +1
# skip +1
# skip +1
# skip +1
#   1% 14/2192 [00:00<00:16, 130.90it/s]skip +1
#   1% 28/2192 [00:00<00:17, 122.28it/s]skip +1
#   2% 53/2192 [00:00<00:18, 117.01it/s]skip +1
# skip +1
# skip +1
#   4% 78/2192 [00:00<00:17, 117.58it/s]skip +1
# skip +1
# skip +1
#   4% 91/2192 [00:00<00:17, 119.73it/s]skip +1
#  11% 247/2192 [00:02<00:17, 110.55it/s]skip +1
#  83% 1821/2192 [00:16<00:03, 114.16it/s]skip +1
# skip +1
#  88% 1929/2192 [00:17<00:02, 113.38it/s]skip +1
#  89% 1941/2192 [00:17<00:02, 114.57it/s]skip +1
# skip +1
#  90% 1978/2192 [00:17<00:01, 113.52it/s]skip +1
#  91% 2003/2192 [00:17<00:01, 113.36it/s]skip +1
# skip +1
#  94% 2064/2192 [00:18<00:01, 110.79it/s]skip +1
# skip +1
#  97% 2124/2192 [00:18<00:00, 110.27it/s]skip +1
#  97% 2136/2192 [00:19<00:00, 112.90it/s]skip +1
#  98% 2148/2192 [00:19<00:00, 114.16it/s]skip +1
# 100% 2192/2192 [00:19<00:00, 112.14it/s]

# %% [markdown]
# ## Create Folders on Your Google Drive to Store Results
#
# If we accidentally close our browser or the Colab runtime disconnects, we will lose all of our training models and progress images.  Therefore we want to store the training data on our Google Drive.  The following cells will help you create a new folder on your Google Drive and then your training data will be stored in this path later

# %%
# !mkdir /content/drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_3 512x512
# !mkdir /content/drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_4

# %% [markdown]
# If you get an error "cannot create directory", it's probably because the folder already exists on your Google Drive and you can ignore the error.

# %% [markdown]
# ## Train from Scratch
#
# This cell block will train StyleGAN from scratch.  Training from scratch is much slower than using *transfer learning* on a previously trained model.  However, the purpose of this tutorial is to a) try training for the first time and b) notice how the progress images develop over time.

# %%
# if you want check the meaning of the parameters in the train.py, you could run this code
# !python train.py --help
# Out:
# Usage: train.py [OPTIONS]
#
#   Train a GAN using the techniques described in the paper "Alias-Free
#   Generative Adversarial Networks".
#
#   Examples:
#
#   # Train StyleGAN3-T for AFHQv2 using 8 GPUs.
#   python train.py --outdir=~/training-runs --cfg=stylegan3-t --data=~/datasets/afhqv2-512x512.zip \
#       --gpus=8 --batch=32 --gamma=8.2 --mirror=1
#
#   # Fine-tune StyleGAN3-R for MetFaces-U using 1 GPU, starting from the pre-trained FFHQ-U pickle.
#   python train.py --outdir=~/training-runs --cfg=stylegan3-r --data=~/datasets/metfacesu-1024x1024.zip \
#       --gpus=8 --batch=32 --gamma=6.6 --mirror=1 --kimg=5000 --snap=5 \
#       --resume=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhqu-1024x1024.pkl
#
#   # Train StyleGAN2 for FFHQ at 1024x1024 resolution using 8 GPUs.
#   python train.py --outdir=~/training-runs --cfg=stylegan2 --data=~/datasets/ffhq-1024x1024.zip \
#       --gpus=8 --batch=32 --gamma=10 --mirror=1 --aug=noaug
#
# Options:
#   --outdir DIR                    Where to save the results  [required]
#   --cfg [stylegan3-t|stylegan3-r|stylegan2]
#                                   Base configuration  [required]
#   --data [ZIP|DIR]                Training data  [required]
#   --gpus INT                      Number of GPUs to use  [x>=1; required]
#   --batch INT                     Total batch size  [x>=1; required]
#   --gamma FLOAT                   R1 regularization weight  [x>=0; required]
#   --cond BOOL                     Train conditional model  [default: False]
#   --mirror BOOL                   Enable dataset x-flips  [default: False]
#   --aug [noaug|ada|fixed]         Augmentation mode  [default: ada]
#   --resume [PATH|URL]             Resume from given network pickle
#   --freezed INT                   Freeze first layers of D  [default: 0; x>=0]
#   --p FLOAT                       Probability for --aug=fixed  [default: 0.2;
#                                   0<=x<=1]
#   --target FLOAT                  Target value for --aug=ada  [default: 0.6;
#                                   0<=x<=1]
#   --batch-gpu INT                 Limit batch size per GPU  [x>=1]
#   --cbase INT                     Capacity multiplier  [default: 32768; x>=1]
#   --cmax INT                      Max. feature maps  [default: 512; x>=1]
#   --glr FLOAT                     G learning rate  [default: varies]  [x>=0]
#   --dlr FLOAT                     D learning rate  [default: 0.002; x>=0]
#   --map-depth INT                 Mapping network depth  [default: varies]
#                                   [x>=1]
#   --mbstd-group INT               Minibatch std group size  [default: 4; x>=1]
#   --desc STR                      String to include in result dir name
#   --metrics [NAME|A,B,C|none]     Quality metrics  [default: fid50k_full]
#   --kimg KIMG                     Total training duration  [default: 25000;
#                                   x>=1]
#   --tick KIMG                     How often to print progress  [default: 4;
#                                   x>=1]
#   --snap TICKS                    How often to save snapshots  [default: 50;
#                                   x>=1]
#   --seed INT                      Random seed  [default: 0; x>=0]
#   --fp32 BOOL                     Disable mixed-precision  [default: False]
#   --nobench BOOL                  Disable cuDNN benchmarking  [default: False]
#   --workers INT                   DataLoader worker processes  [default: 3;
#                                   x>=1]
#   -n, --dry-run                   Print training options and exit
#   --help                          Show this message and exit.

# %%
#######################################################
#      set --outdir= as the directory you want to store your training result
#      set --data= as the compressed zip file generated by the dataset_tool.py from above
#######################################################

# train the model
# !python train.py --outdir=../drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_4 --cfg=stylegan3-r --data=./datasets/customdataset.zip  --gpus=1 --batch=32 --gamma=0.5 --batch-gpu=16 --snap=2 --workers=2
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9988915792636801,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 0.5,
#     "blur_init_sigma": 10,
#     "blur_fade_kimg": 200.0
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 2
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./datasets/customdataset.zip",
#     "use_labels": false,
#     "max_size": 2165,
#     "xflip": false,
#     "resolution": 128,
#     "random_seed": 0
#   },
#   "num_gpus": 1,
#   "batch_size": 32,
#   "batch_gpu": 16,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "total_kimg": 25000,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 2,
#   "network_snapshot_ticks": 2,
#   "random_seed": 0,
#   "ema_kimg": 10.0,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "ada_target": 0.6,
#   "run_dir": "../drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_4/00000-stylegan3-r-customdataset-gpus1-batch32-gamma0.5"
# }
#
# Output directory:    ../drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_4/00000-stylegan3-r-customdataset-gpus1-batch32-gamma0.5
# Number of GPUs:      1
# Batch size:          32 images
# Training duration:   25000 kimg
# Dataset path:        ./datasets/customdataset.zip
# Dataset size:        2165 images
# Dataset resolution:  128
# Dataset labels:      False
# Dataset x-flips:     False
#
# Creating output directory...
# Launching processes...
# Loading training set...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
#   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
#
# Num images:  2165
# Image shape: [3, 128, 128]
# Label shape: [0]
#
# Constructing networks...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
#
# Generator                     Parameters  Buffers  Output shape          Datatype
# ---                           ---         ---      ---                   ---
# mapping.fc0                   262656      -        [16, 512]             float32
# mapping.fc1                   262656      -        [16, 512]             float32
# mapping                       -           512      [16, 16, 512]         float32
# synthesis.input.affine        2052        -        [16, 4]               float32
# synthesis.input               1048576     3081     [16, 1024, 36, 36]    float32
# synthesis.L0_36_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L0_36_1024          1049600     157      [16, 1024, 36, 36]    float16
# synthesis.L1_36_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L1_36_1024          1049600     157      [16, 1024, 36, 36]    float16
# synthesis.L2_36_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L2_36_1024          1049600     157      [16, 1024, 36, 36]    float16
# synthesis.L3_52_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L3_52_1024          1049600     169      [16, 1024, 52, 52]    float16
# synthesis.L4_52_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L4_52_1024          1049600     157      [16, 1024, 52, 52]    float16
# synthesis.L5_52_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L5_52_1024          1049600     157      [16, 1024, 52, 52]    float16
# synthesis.L6_84_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L6_84_1024          1049600     169      [16, 1024, 84, 84]    float16
# synthesis.L7_84_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L7_84_1024          1049600     157      [16, 1024, 84, 84]    float16
# synthesis.L8_84_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L8_84_1024          1049600     157      [16, 1024, 84, 84]    float16
# synthesis.L9_148_1024.affine  525312      -        [16, 1024]            float32
# synthesis.L9_148_1024         1049600     169      [16, 1024, 148, 148]  float16
# synthesis.L10_148_912.affine  525312      -        [16, 1024]            float32
# synthesis.L10_148_912         934800      157      [16, 912, 148, 148]   float16
# synthesis.L11_148_683.affine  467856      -        [16, 912]             float32
# synthesis.L11_148_683         623579      157      [16, 683, 148, 148]   float16
# synthesis.L12_148_512.affine  350379      -        [16, 683]             float32
# synthesis.L12_148_512         350208      25       [16, 512, 148, 148]   float16
# synthesis.L13_128_512.affine  262656      -        [16, 512]             float32
# synthesis.L13_128_512         262656      25       [16, 512, 128, 128]   float16
# synthesis.L14_128_3.affine    262656      -        [16, 512]             float32
# synthesis.L14_128_3           1539        1        [16, 3, 128, 128]     float16
# synthesis                     -           -        [16, 3, 128, 128]     float32
# ---                           ---         ---      ---                   ---
# Total                         21366701    5564     -                     -
#
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Discriminator  Parameters  Buffers  Output shape         Datatype
# ---            ---         ---      ---                  ---
# b128.fromrgb   1024        16       [16, 256, 128, 128]  float16
# b128.skip      131072      16       [16, 512, 64, 64]    float16
# b128.conv0     590080      16       [16, 256, 128, 128]  float16
# b128.conv1     1180160     16       [16, 512, 64, 64]    float16
# b128           -           16       [16, 512, 64, 64]    float16
# b64.skip       262144      16       [16, 512, 32, 32]    float16
# b64.conv0      2359808     16       [16, 512, 64, 64]    float16
# b64.conv1      2359808     16       [16, 512, 32, 32]    float16
# b64            -           16       [16, 512, 32, 32]    float16
# b32.skip       262144      16       [16, 512, 16, 16]    float16
# b32.conv0      2359808     16       [16, 512, 32, 32]    float16
# b32.conv1      2359808     16       [16, 512, 16, 16]    float16
# b32            -           16       [16, 512, 16, 16]    float16
# b16.skip       262144      16       [16, 512, 8, 8]      float16
# b16.conv0      2359808     16       [16, 512, 16, 16]    float16
# b16.conv1      2359808     16       [16, 512, 8, 8]      float16
# b16            -           16       [16, 512, 8, 8]      float16
# b8.skip        262144      16       [16, 512, 4, 4]      float32
# b8.conv0       2359808     16       [16, 512, 8, 8]      float32
# b8.conv1       2359808     16       [16, 512, 4, 4]      float32
# b8             -           16       [16, 512, 4, 4]      float32
# b4.mbstd       -           -        [16, 513, 4, 4]      float32
# b4.conv        2364416     16       [16, 512, 4, 4]      float32
# b4.fc          4194816     -        [16, 512]            float32
# b4.out         513         -        [16, 1]              float32
# ---            ---         ---      ---                  ---
# Total          28389121    352      -                    -
#
# Setting up augmentation...
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# 2023-11-15 19:12:19.847438: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-15 19:12:19.847497: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-15 19:12:19.847545: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-15 19:12:19.856905: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-15 19:12:21.084478: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Training for 25000 kimg...
#
# tick 0     kimg 0.0      time 3m 57s       sec/tick 30.0    sec/kimg 936.60  maintenance 207.4  cpumem 4.70   gpumem 12.56  reserved 12.94  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 461.59812072785246}, "metric": "fid50k_full", "total_time": 2568.5948231220245, "total_time_str": "42m 49s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1700078196.5020232}
# tick 1     kimg 4.0      time 1h 02m 34s   sec/tick 892.7   sec/kimg 223.19  maintenance 2624.1 cpumem 5.19   gpumem 8.63   reserved 13.42  augment 0.000
# tick 2     kimg 8.0      time 1h 17m 29s   sec/tick 894.4   sec/kimg 223.61  maintenance 0.2    cpumem 5.19   gpumem 8.63   reserved 13.42  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 370.2603829577304}, "metric": "fid50k_full", "total_time": 2540.324259519577, "total_time_str": "42m 20s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000008.pkl", "timestamp": 1700082580.380517}
# tick 3     kimg 12.0     time 2h 15m 41s   sec/tick 895.2   sec/kimg 223.79  maintenance 2596.5 cpumem 5.16   gpumem 8.63   reserved 13.42  augment 0.000
# tick 4     kimg 16.0     time 2h 30m 36s   sec/tick 895.6   sec/kimg 223.91  maintenance 0.0    cpumem 5.16   gpumem 8.63   reserved 13.42  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 356.85394705561464}, "metric": "fid50k_full", "total_time": 2539.302635192871, "total_time_str": "42m 19s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000016.pkl", "timestamp": 1700086965.852204}
# tick 5     kimg 20.0     time 3h 28m 47s   sec/tick 896.4   sec/kimg 224.11  maintenance 2594.7 cpumem 5.20   gpumem 8.63   reserved 13.42  augment 0.000

# %%
#######################################################
#      optional: fine tune a pretrained model
#                but you need to resize the images to fit the pre-trained model
#######################################################

# you could also fine a StyleGan3: Fine-tune StyleGAN3-R for MetFaces-U using 1 GPU, starting from the pre-trained FFHQ-U pickle.
# !python train.py --outdir=../drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_3 --cfg=stylegan3-t --data=./datasets/customdataset.zip --gpus=1 --batch=32 --gamma=8 --batch-gpu=8 --snap=1 --workers=2 \
--resume=../drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_3/00005-stylegan3-t-customdataset-gpus1-batch64-gamma2/network-snapshot-000310.pkl
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9988915792636801,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 0.5,
#     "blur_init_sigma": 0,
#     "blur_fade_kimg": 200.0
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 2
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./datasets/customdataset.zip",
#     "use_labels": false,
#     "max_size": 2165,
#     "xflip": false,
#     "resolution": 128,
#     "random_seed": 0
#   },
#   "num_gpus": 1,
#   "batch_size": 32,
#   "batch_gpu": 16,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "total_kimg": 25000,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 2,
#   "network_snapshot_ticks": 2,
#   "random_seed": 0,
#   "ema_kimg": 10.0,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "ada_target": 0.6,
#   "resume_pkl": "../drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_4/00002-stylegan3-r-customdataset-gpus1-batch32-gamma0.5/network-snapshot-000008.pkl",
#   "ada_kimg": 100,
#   "ema_rampup": null,
#   "run_dir": "../drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_4/00003-stylegan3-r-customdataset-gpus1-batch32-gamma0.5"
# }
#
# Output directory:    ../drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_4/00003-stylegan3-r-customdataset-gpus1-batch32-gamma0.5
# Number of GPUs:      1
# Batch size:          32 images
# Training duration:   25000 kimg
# Dataset path:        ./datasets/customdataset.zip
# Dataset size:        2165 images
# Dataset resolution:  128
# Dataset labels:      False
# Dataset x-flips:     False
#
# Creating output directory...
# Launching processes...
# Loading training set...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
#   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
#
# Num images:  2165
# Image shape: [3, 128, 128]
# Label shape: [0]
#
# Constructing networks...
# Resuming from "../drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_result_test_4/00002-stylegan3-r-customdataset-gpus1-batch32-gamma0.5/network-snapshot-000008.pkl"
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
#
# Generator                     Parameters  Buffers  Output shape          Datatype
# ---                           ---         ---      ---                   ---
# mapping.fc0                   262656      -        [16, 512]             float32
# mapping.fc1                   262656      -        [16, 512]             float32
# mapping                       -           512      [16, 16, 512]         float32
# synthesis.input.affine        2052        -        [16, 4]               float32
# synthesis.input               1048576     3081     [16, 1024, 36, 36]    float32
# synthesis.L0_36_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L0_36_1024          1049600     157      [16, 1024, 36, 36]    float16
# synthesis.L1_36_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L1_36_1024          1049600     157      [16, 1024, 36, 36]    float16
# synthesis.L2_36_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L2_36_1024          1049600     157      [16, 1024, 36, 36]    float16
# synthesis.L3_52_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L3_52_1024          1049600     169      [16, 1024, 52, 52]    float16
# synthesis.L4_52_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L4_52_1024          1049600     157      [16, 1024, 52, 52]    float16
# synthesis.L5_52_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L5_52_1024          1049600     157      [16, 1024, 52, 52]    float16
# synthesis.L6_84_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L6_84_1024          1049600     169      [16, 1024, 84, 84]    float16
# synthesis.L7_84_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L7_84_1024          1049600     157      [16, 1024, 84, 84]    float16
# synthesis.L8_84_1024.affine   525312      -        [16, 1024]            float32
# synthesis.L8_84_1024          1049600     157      [16, 1024, 84, 84]    float16
# synthesis.L9_148_1024.affine  525312      -        [16, 1024]            float32
# synthesis.L9_148_1024         1049600     169      [16, 1024, 148, 148]  float16
# synthesis.L10_148_912.affine  525312      -        [16, 1024]            float32
# synthesis.L10_148_912         934800      157      [16, 912, 148, 148]   float16
# synthesis.L11_148_683.affine  467856      -        [16, 912]             float32
# synthesis.L11_148_683         623579      157      [16, 683, 148, 148]   float16
# synthesis.L12_148_512.affine  350379      -        [16, 683]             float32
# synthesis.L12_148_512         350208      25       [16, 512, 148, 148]   float16
# synthesis.L13_128_512.affine  262656      -        [16, 512]             float32
# synthesis.L13_128_512         262656      25       [16, 512, 128, 128]   float16
# synthesis.L14_128_3.affine    262656      -        [16, 512]             float32
# synthesis.L14_128_3           1539        1        [16, 3, 128, 128]     float16
# synthesis                     -           -        [16, 3, 128, 128]     float32
# ---                           ---         ---      ---                   ---
# Total                         21366701    5564     -                     -
#
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Discriminator  Parameters  Buffers  Output shape         Datatype
# ---            ---         ---      ---                  ---
# b128.fromrgb   1024        16       [16, 256, 128, 128]  float16
# b128.skip      131072      16       [16, 512, 64, 64]    float16
# b128.conv0     590080      16       [16, 256, 128, 128]  float16
# b128.conv1     1180160     16       [16, 512, 64, 64]    float16
# b128           -           16       [16, 512, 64, 64]    float16
# b64.skip       262144      16       [16, 512, 32, 32]    float16
# b64.conv0      2359808     16       [16, 512, 64, 64]    float16
# b64.conv1      2359808     16       [16, 512, 32, 32]    float16
# b64            -           16       [16, 512, 32, 32]    float16
# b32.skip       262144      16       [16, 512, 16, 16]    float16
# b32.conv0      2359808     16       [16, 512, 32, 32]    float16
# b32.conv1      2359808     16       [16, 512, 16, 16]    float16
# b32            -           16       [16, 512, 16, 16]    float16
# b16.skip       262144      16       [16, 512, 8, 8]      float16
# b16.conv0      2359808     16       [16, 512, 16, 16]    float16
# b16.conv1      2359808     16       [16, 512, 8, 8]      float16
# b16            -           16       [16, 512, 8, 8]      float16
# b8.skip        262144      16       [16, 512, 4, 4]      float32
# b8.conv0       2359808     16       [16, 512, 8, 8]      float32
# b8.conv1       2359808     16       [16, 512, 4, 4]      float32
# b8             -           16       [16, 512, 4, 4]      float32
# b4.mbstd       -           -        [16, 513, 4, 4]      float32
# b4.conv        2364416     16       [16, 512, 4, 4]      float32
# b4.fc          4194816     -        [16, 512]            float32
# b4.out         513         -        [16, 1]              float32
# ---            ---         ---      ---                  ---
# Total          28389121    352      -                    -
#
# Setting up augmentation...
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# 2023-11-18 04:52:20.150604: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-18 04:52:20.150649: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-18 04:52:20.150676: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-18 04:52:21.112957: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Training for 25000 kimg...
#
# tick 0     kimg 0.0      time 3m 39s       sec/tick 29.0    sec/kimg 905.88  maintenance 190.4  cpumem 4.98   gpumem 12.56  reserved 12.95  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 282.86001590727096}, "metric": "fid50k_full", "total_time": 2590.5156660079956, "total_time_str": "43m 11s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1700285812.5264595}
# tick 1     kimg 4.0      time 1h 03m 00s   sec/tick 918.7   sec/kimg 229.67  maintenance 2641.6 cpumem 5.46   gpumem 8.63   reserved 13.40  augment 0.004
# tick 2     kimg 8.0      time 1h 18m 20s   sec/tick 920.0   sec/kimg 230.01  maintenance 0.2    cpumem 5.46   gpumem 8.63   reserved 11.30  augment 0.001
# Evaluating metrics...
# {"results": {"fid50k_full": 355.2788738078183}, "metric": "fid50k_full", "total_time": 2551.601748943329, "total_time_str": "42m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000008.pkl", "timestamp": 1700290253.5047858}
# tick 3     kimg 12.0     time 2h 17m 02s   sec/tick 919.6   sec/kimg 229.90  maintenance 2602.0 cpumem 5.44   gpumem 8.63   reserved 11.30  augment 0.014
# tick 4     kimg 16.0     time 2h 32m 22s   sec/tick 920.7   sec/kimg 230.18  maintenance 0.0    cpumem 5.44   gpumem 8.63   reserved 11.30  augment 0.018
# Evaluating metrics...
# {"results": {"fid50k_full": 332.28851973542805}, "metric": "fid50k_full", "total_time": 2547.5692596435547, "total_time_str": "42m 28s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000016.pkl", "timestamp": 1700294692.0099058}
# tick 5     kimg 20.0     time 3h 30m 56s   sec/tick 915.7   sec/kimg 228.93  maintenance 2598.2 cpumem 5.44   gpumem 8.64   reserved 11.30  augment 0.045
# tick 6     kimg 24.0     time 3h 46m 10s   sec/tick 913.6   sec/kimg 228.40  maintenance 0.2    cpumem 5.44   gpumem 8.65   reserved 11.30  augment 0.082
# Evaluating metrics...
# {"results": {"fid50k_full": 380.5296634810759}, "metric": "fid50k_full", "total_time": 2532.663820505142, "total_time_str": "42m 13s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000024.pkl", "timestamp": 1700299104.228499}Traceback (most recent call last):
#
# Exception ignored in: Exception ignored in sys.unraisablehook

# %% [markdown]
# ## Wait an Hour or Two
#
# Normal training of a dataset can take days.  For this demonstration, we only want to train for a few hours in order to get familiar with the training process and see the initial results.
#
# Results are stored in your Google Drive under your custom path defined above.
#
# Each training run is stored in a separate directory.  The initial training run is stored in `00000-customdataset...`.  If you run training twice, the second run will be stored in `00001-customdataset...`.  And so on.
#
# Inside the training run directory you will see various files.  `reals.png` shows a sample of the training dataset.  You should see various your custom images in this image. `fakes000000.png` is a sample of generated images from the initial model.  `network-snapshot-XXXXXX.pkl` is the actual model which can be used later to generate "fake" images, videos, etc.
#
# As training progresses you will see more `fakes` & `network-snapshot` files created.
#
# Since we only want to test a training, once you get to around the 500th iteration, you can stop the above training cell.  Then take a look at the `fakes` images and familiarize yourself with how the training progresses.

# %% [markdown]
# ## Generate images

# %%
#######################################################
#      set the directory where you want to store the new generated images
#######################################################

# make a directory to store newly generated images
# !mkdir /content/drive/MyDrive/MDE/SCI6485/StyleGan/generated_images_2
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/MDE/SCI6485/StyleGan/generated_images’: File exists

# %%
#######################################################
#      set --outdir= as the path above
#      set --network= as the training result snapshot you want to use for generating the image
#######################################################

# load the training result and generate a new image
# the new images will be stored in the path you created above
# !python gen_images.py --outdir=/content/drive/MyDrive/MDE/SCI6485/StyleGan/generated_images_2 --trunc=1 --seeds=2 \
    --network=/content/drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_2/00000-stylegan3-t-customdataset-gpus1-batch32-gamma10/network-snapshot-000012.pkl
# Out:
# Loading networks from "/content/drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_2/00000-stylegan3-t-customdataset-gpus1-batch32-gamma10/network-snapshot-000012.pkl"...
# Traceback (most recent call last):
#   File "/content/stylegan3/gen_images.py", line 143, in <module>
#     generate_images() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/content/stylegan3/gen_images.py", line 107, in generate_images
#     with dnnlib.util.open_url(network_pkl) as f:
#   File "/content/stylegan3/dnnlib/util.py", line 403, in open_url
#     return url if return_filename else open(url, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/MDE/SCI6485/StyleGan/custom_data_2/00000-stylegan3-t-customdataset-gpus1-batch32-gamma10/network-snapshot-000012.pkl'
